# %% [markdown]
# ## Current Live

# %%
from googleapiclient.discovery import build

def get_live_stream_links(api_key, channel_id):
    youtube = build('youtube', 'v3', developerKey=api_key)

    request = youtube.search().list(
        part='snippet',
        channelId=channel_id,
        maxResults=50,  # Change if needed
        type='video',  # To get videos only
        eventType='live',  # To get live streams
        order='date'  # To get the latest videos first
    )
    response = request.execute()

    live_stream_links = []
    for item in response.get('items', []):
        video_id = item['id'].get('videoId')
        if video_id:
            live_stream_links.append(f"https://www.youtube.com/watch?v={video_id}")

    return live_stream_links

# Use the function
api_key = "AIzaSyA40a_kzMUZ_I98GXkovDagFlOyvGdw1sk"
channel_id = "UCDuKCDCSqim67hE-oTDx77Q"
live_stream_links = get_live_stream_links(api_key, channel_id)
for link in live_stream_links:
    print(link)

# %% [markdown]
# ## Previous Live

# %%
from googleapiclient.discovery import build

def get_previous_live_stream_links(api_key, channel_id):
    youtube = build('youtube', 'v3', developerKey=api_key)

    request = youtube.search().list(
        part='snippet',
        channelId=channel_id,
        maxResults=50,  # Change if needed
        type='video',  # To get videos only
        eventType='completed',  # To get completed live streams
        order='date'  # To get the latest videos first
    )
    response = request.execute()

    previous_live_stream_links = []
    for item in response.get('items', []):
        video_id = item['id'].get('videoId')
        if video_id:
            previous_live_stream_links.append(f"https://www.youtube.com/watch?v={video_id}")

    return previous_live_stream_links

# %%
# Use the function
api_key = "AIzaSyA40a_kzMUZ_I98GXkovDagFlOyvGdw1sk"
channel_id = "UC4R4QiI5TSde73benpVKjUA"
previous_live_stream_links = get_previous_live_stream_links(api_key, channel_id)
len(previous_live_stream_links)
# Out:
# 0

# %%
from googleapiclient.discovery import build


def get_all_video_ids(api_key, channel_id):
    """
    Retrieves all video IDs for a given YouTube channel using pagination.

    Args:
        api_key: Your YouTube Data API v3 key.
        channel_id: The ID of the channel to retrieve videos from.

    Returns:
        A list of video IDs for the specified channel.
    """

    youtube = build('youtube', 'v3', developerKey=api_key)

    request = youtube.search().list(
        part='snippet',
        channelId=channel_id,
        maxResults=50,  # Change if needed (default quota is 50 per request)
        type='video',  # To get only videos
        eventType='completed'  # To get completed live streams
    )

    all_video_ids = []
    while True:
        response = request.execute()

        # Extract video IDs from the response
        video_ids = [item['id']['videoId'] for item in response.get('items', []) if item['id'].get('videoId')]
        all_video_ids.extend(video_ids)

        # Check for next page token and break if no more pages
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break

        # Update request with next page token for pagination
        request = youtube.search().list(
            part='snippet',
            channelId=channel_id,
            maxResults=50,
            type='video',
            eventType='completed',  # To get completed live streams
            pageToken=next_page_token
        )

    return all_video_ids

# %%
channel_id = "UCDuKCDCSqim67hE-oTDx77Q"

# %%
all_video_ids3 = get_all_video_ids(api_key, channel_id)

# %%
len(set(all_video_ids3))
# Out:
# 484

# %%
for link in all_video_ids[:4]:
    print(link)
# Out:
# hKnzkFGQk3I
# I5OqHKC8KvE
# RmbIJC0r9uI
# SwZcUSmSEds

# %%
print(len(set(all_video_ids)))
# Out:
# 502

# %%
all_video_ids2.extend(all_video_ids3)

# %%
print(len(all_video_ids2))
print(len(set(all_video_ids2)))
# Out:
# 988
# 498

# %%
import requests
from bs4 import BeautifulSoup

def get_video_links(playlist_url):
    # Fetch the playlist page
    page = requests.get(playlist_url)
    
    # Parse the HTML content
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Find all elements with class "yt-simple-endpoint style-scope ytd-playlist-video-renderer"
    video_elements = soup.find_all("a", class_="yt-simple-endpoint style-scope ytd-playlist-video-renderer")
    
    # Extract video links from the elements
    video_links = []
    for element in video_elements:
        href = element.get('href')
        if href.startswith('/watch'):
            video_links.append('https://www.youtube.com' + href)
    
    return video_links

# Example usage
playlist_url = "https://www.youtube.com/playlist?list=PLq71IJk8mCV5H0X__3DXxROWn11hXN8Zk"
video_links = get_video_links(playlist_url)
print(video_links)
# Out:
# []

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from pytube import Playlist

def get_video_links(playlist_url):
    # Create a Playlist object
    playlist = Playlist(playlist_url)
    
    # Extract video URLs
    video_links = playlist.video_urls
    
    return video_links

# Example usage
playlist_url = "https://www.youtube.com/playlist?list=PLq71IJk8mCV5H0X__3DXxROWn11hXN8Zk"
video_links = get_video_links(playlist_url)
print(video_links[:5])
# Out:
# ['https://www.youtube.com/watch?v=SgqeN_FUprg', 'https://www.youtube.com/watch?v=w6a9wvFugT4', 'https://www.youtube.com/watch?v=hF6XlcgnE10', 'https://www.youtube.com/watch?v=TnIk0dbrD04', 'https://www.youtube.com/watch?v=8pac77058GA']

# %%
len(set(video_links))
# Out:
# 654

# %%
playlist = Playlist(playlist_url)
playlist.title
playlist.length
# Out:
# 703

# %%
yt = YouTube(video_links[0])
yt.length
# Out:
# 3159

# %%
playlist._playlist_id
# Out:
# 'PLq71IJk8mCV5H0X__3DXxROWn11hXN8Zk'

# %%
from pytube import Playlist
from pytube import YouTube

def get_video_information(video_url):
    # Create a YouTube object
    yt = YouTube(video_url)
    
    # Extract video information
    title = yt.title
    views = yt.views
    length = yt.length
    return {
        "title": title,
        "views": views,
        "length": length,
        "url": video_url,

    }

def get_playlist_information(playlist_url):
    # Create a Playlist object
    playlist = Playlist(playlist_url)
    
    # Extract video URLs
    video_links = playlist.video_urls
    
    # Get information for each video
    video_information = []
    for video_link in video_links:
        info = get_video_information(video_link)
        video_information.append(info)
    
    return video_information

# %%
# Example usage
playlist_url = "https://www.youtube.com/playlist?list=PLq71IJk8mCV5H0X__3DXxROWn11hXN8Zk"
playlist_information = get_playlist_information(playlist_url)
# for index, video_info in enumerate(playlist_information, start=1):
#     print(f"Video {index}:")
#     print("Title:", video_info["title"])
#     print("Views:", video_info["views"])
#     print("url:", video_info["url"])
#     print()

# %%
import pandas as pd
df = pd.DataFrame(playlist_information)
print(df.shape)
df
# Out:
# (654, 4)
#                                                  title    views  length  \
# 0    Sunday Suspense | Professor Shonku | Compu | S...   434508    3159
# 1    Sunday Suspense Classics | Satyajit Ray Storie...   372088    5062
# 2    Sunday Suspense | Chowdhury Barir Rahasya | Ab...  1044481   16188
# 3    Sunday Suspense Classics | Bibhutibhushan Band...   541792    2692
# 4    Sunday Suspense | Neel Arshola | Himadri Kisho...   596493    2342
# ..                                                 ...      ...     ...
# 649  #SundaySuspense | Motibibir Darga | Syed Musta...   671732    1941
# 650  #SundaySuspense | Telephone | Hemendra Kumar R...   270039    1114
# 651  Sunday Suspense Classics | Satyajit Ray Short ...   163049    4797
# 652  Sunday Suspense | Feluda | Bhuswargo Bhayankor...   348093    5535
# 653  Sunday Suspense | Nishithey | Rabindranath Tag...    62553    4670
#
#                                              url
# 0    https://www.youtube.com/watch?v=SgqeN_FUprg
# 1    https://www.youtube.com/watch?v=w6a9wvFugT4
# 2    https://www.youtube.com/watch?v=hF6XlcgnE10
# 3    https://www.youtube.com/watch?v=TnIk0dbrD04
# 4    https://www.youtube.com/watch?v=8pac77058GA
# ..                                           ...
# 649  https://www.youtube.com/watch?v=YTvFY4r1zVU
# 650  https://www.youtube.com/watch?v=t8VmaNimxAQ
# 651  https://www.youtube.com/watch?v=wAgWlo7lmXc
# 652  https://www.youtube.com/watch?v=C_QFKUkUkaU
# 653  https://www.youtube.com/watch?v=FLkLjL8Zm2w
#
# [654 rows x 4 columns]

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (654, 4)

# %%
for index, row in df[:20].iterrows():
    print(row['title'], row['views'])
    print()
# Out:
# Sunday Suspense | Professor Shonku | Compu | Satyajit Ray | Mirchi Bangla 434456
#
# Sunday Suspense Classics | Satyajit Ray Stories | Mirchi Bangla 372040
#
# Sunday Suspense | Chowdhury Barir Rahasya | Abhirup Sarkar | Mirchi Bangla 1044318
#
# Sunday Suspense Classics | Bibhutibhushan Bandyopadhyay | Aloukik Golpo | Mirchi Bangla 541752
#
# Sunday Suspense | Neel Arshola | Himadri Kishore Dasgupta | Mirchi Bangla 596465
#
# Sunday Suspense | Professor Shonku Adventures | Satyajit Ray | Mirchi Bangla 400737
#
# Sunday Suspense | Aagun Paharer Punthi | Caesar Bagchi | Mirchi Bangla 817546
#
# #SundaySuspense | Pashobik | Anish Deb | Mirchi Bangla 489224
#
# Sunday Suspense | Charlie | Ranadip Nandy | Mirchi Bangla 640335
#
# Sunday Suspense Classics | Baroda | Akashbani - Maalkosh - Sabuj Chashma | Mirchi Bangla 546512
#
# Sunday Suspense | Byomkesh | Banhi Patanga | Saradindu Bandopadhyay | Mirchi Bangla 1308754
#
# Sunday Suspense Classics | Saradindu Bandyopadhyay | Dehantar | Mirchi Bangla 553702
#
# Sunday Suspense | Ben Hur : Complete Saga | Lew Wallace | Mirchi Bangla 116932
#
# Sunday Suspense | Full Episode | Arjun | Jutoy Rokter Daag | Samaresh Majumdar | Mirchi Bangla 222789
#
# Sunday Suspense Full Episode  | Taranath | Brojobhushan-er Biswasprapti  | Taradas Bandopadhyay 287777
#
# Sunday Suspense | Jhinder Bandi Part 7 | Saradindu Bandyopadhyay | Mirchi Bangla 145493
#
# Sunday Suspense | Jhinder Bandi Part 6 | Saradindu Bandyopadhyay | Mirchi Bangla 160699
#
# Sunday Suspense | Jhinder Bandi Part 5 | Saradindu Bandyopadhyay | Mirchi Bangla 152206
#
# Sunday Suspense | Jhinder Bandi Part 4 | Saradindu Bandyopadhyay | Mirchi Bangla 196160
#
# Sunday Suspense Classics | Saradindu Bandyopadhyay | Ghora Ghora Kando | Mirchi Bangla 162966

# %%
playlist.title
# Out:
# 'Sunday Suspense all Episodes'

# %%
df.to_csv('sunday_suspense_all.csv', index=False)
