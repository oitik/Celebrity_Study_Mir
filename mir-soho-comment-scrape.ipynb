# %%
# Regular EDA(exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
# %matplotlib inline

from tqdm import tqdm
import string
import statistics
import re
import joblib
import random
import statistics
from collections import Counter
from scipy import stats
import os
# import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics.pairwise import cosine_similarity
import zipfile
from matplotlib.lines import Line2D

# %% [markdown]
# ## Check the video infos

# %%
mir_soho_vi = pd.read_csv('/kaggle/input/media-study2-0/mir_soho_vi.csv')
mir_soho_vi.head()

# %%
mir_chara_vi = pd.read_csv('/kaggle/input/media-study2-0/mir_chara_vi.csv')
mir_chara_vi.head()

# %%
mirer_thek_vi = pd.read_csv('/kaggle/input/media-study2-0/mirer_thek_vi.csv')
mirer_thek_vi.head()

# %%
print(mir_chara_vi.shape)
print(mir_soho_vi.shape)
print(mirer_thek_vi.shape)

# %%
# mirer_thek_vi[['date', 'time']] = mirer_thek_vi['posted_at'].str.split('T', expand=True)
# mirer_thek_vi['time'] = mirer_thek_vi['time'].str[:-1]
# mirer_thek_vi.drop(columns=['posted_at'], inplace=True)
# mirer_thek_vi['date'] = pd.to_datetime(mirer_thek_vi['date'])
# mirer_thek_vi['time'] = pd.to_datetime(mirer_thek_vi['time'],format='%H:%M:%S').dt.time
# mirer_thek_vi.head(2)

# %%
def preprocess_df(df):
    # Split the 'posted_at' column into separate 'date' and 'time' columns
    df[['date', 'time']] = df['posted_at'].str.split('T', expand=True)
    
    # Remove the last character ('Z') from the 'time' column
    df['time'] = df['time'].str[:-1]
    
    # Drop the original 'posted_at' column
    df.drop(columns=['posted_at'], inplace=True)
    
    # Convert 'date' and 'time' columns to datetime format
    df['date'] = pd.to_datetime(df['date'])
    df['time'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.time
    
    return df

# %%
mirer_thek_vi = preprocess_df(mirer_thek_vi)
mir_soho_vi = preprocess_df(mir_soho_vi)
mir_chara_vi = preprocess_df(mir_chara_vi)
mirer_thek_vi.head(2)

# %%
mirer_thek_vids = mirer_thek_vi['video_id']
mir_soho_vids = mir_soho_vi['video_id']
mir_chara_vids = mir_chara_vi['video_id']
mirer_thek_vids[:5]

# %%
mir_soho_vi['year'] = mir_soho_vi['date'].dt.year
mir_soho_vi.year.value_counts().sort_index().plot(kind='bar')

# %%
mir_soho_vi.year.value_counts().sort_index()

# %%
mir_soho_vif = mir_soho_vi[(mir_soho_vi['date'].dt.year >= 2019) & (mir_soho_vi['date'].dt.year < 2024)].copy()
mir_soho_vif.year.value_counts().sort_index()

# %%
mir_chara_vi['year'] = mir_chara_vi['date'].dt.year
print(mir_chara_vi.year.value_counts().sort_index())
mir_chara_vi.year.value_counts().sort_index().plot(kind='bar')

# %%
mirer_thek_vi['year'] = mirer_thek_vi['date'].dt.year
print(mirer_thek_vi.year.value_counts().sort_index())
mirer_thek_vi.year.value_counts().sort_index().plot(kind='bar');

# %%
mirer_thek_vi.drop(['year'],axis=1, inplace=True)
mirer_thek_vi.head(2)

# %%
mir_chara_vi.drop(['year'],axis=1, inplace=True)
mir_chara_vi.head(2)

# %%
mir_soho_vif.drop(['year'],axis=1, inplace=True)
mir_soho_vif.head(2)

# %%
mir_soho_vif.shape

# %%
# mir_soho_vif.to_csv('mir_soho_vif.csv', index=False)
# mir_chara_vi.to_csv('mir_chara_vif.csv', index=False)
# mirer_thek_vi.to_csv('mirer_thek_vif.csv', index=False)

# %%
mir_soho_vi = pd.read_csv('/kaggle/input/media-study2-0/final_video_info/mir_soho_vif.csv')
mir_chara_vi = pd.read_csv('/kaggle/input/media-study2-0/final_video_info/mir_chara_vif.csv')
mirer_thek_vi = pd.read_csv('/kaggle/input/media-study2-0/final_video_info/mirer_thek_vif.csv')


print(mir_soho_vi.shape)
print(mir_chara_vi.shape)
print(mirer_thek_vi.shape)


mir_soho_vids = mir_soho_vi['video_id']
mir_chara_vids = mir_chara_vi['video_id']
mirer_thek_vids = mirer_thek_vi['video_id']

mirer_thek_vids[:5]
# Out:
# (180, 9)
# (246, 9)
# (70, 9)
# 0    EcIDh5OEOyo
# 1    eyP_97FAtUk
# 2    ilh_ItHeXtU
# 3    FOn3lGHxnhw
# 4    Sf2UpyxDfkg
# Name: video_id, dtype: object

# %%
import googleapiclient.discovery

# oitik
# dev = "AIzaSyA40a_kzMUZ_I98GXkovDagFlOyvGdw1sk" #tanbirjubayer@gmail.com
# dev = "AIzaSyBl6MiOPw9Z3XpgqTaTWrvhLyMlg5xaj4U" #tanbeerjubaer@gmail.com
# dev = "AIzaSyCnsX8TOPguDzGexVlXkoW6FRE3zqsOzJY"
# dev = "AIzaSyBWxf1d5J03NflJTLcTn6WPePEA1jL10do"
# Barisha
# dev = "AIzaSyBk9BnvecwYzX03pHU5ch6Sw1n995xJtfw" #@gmail.com
# dev = "AIzaSyBsusrGIzo1kd_4dRAOBct09wnoA44WWog" #@gmail.com
# dev = "AIzaSyA8TU-2YrZ1HWO6ktwAq-3G9pf6MgOz71E" #@gmail.com

# # Nannu
# dev = "AIzaSyAs1EbnLeZVOiQ0OCDZZsCCIb8F2Sd2bDg"
dev = "AIzaSyD2TPx6ZYcL6b6fRxJu-NRLvPJ83dKcnlM"

# # Po
# dev = "AIzaSyAZO9KtmMYkfVdOprkPEr30ZAz6pQqdEoo"


api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

youtube

# %%
def get_comments(vid):
    comments = []

    # Retrieve top-level comments
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=vid,
        maxResults=100
    )

    while request:
        response = request.execute()

        for item in response["items"]:
            # Extract top-level comment
            top_level_comment = item["snippet"]["topLevelComment"]["snippet"]
            
            # Extract date and time separately from publishedAt
            published_at = top_level_comment["publishedAt"]
            published_date, published_time = published_at.split('T')
            
            comments.append([
                top_level_comment["authorDisplayName"],
                published_date,  # Separate column for date
                published_time,  # Separate column for time
                top_level_comment["likeCount"],
                top_level_comment["textOriginal"],
                top_level_comment["videoId"],
#                 item["snippet"]["isPublic"]
            ])

            # Check for replies to the top-level comment
            if item["snippet"]["totalReplyCount"] > 0:
                # Retrieve replies
                replies_request = youtube.comments().list(
                    part="snippet",
                    parentId=item["snippet"]["topLevelComment"]["id"],
                    maxResults=100
                )

                replies_response = replies_request.execute()

                for reply_item in replies_response["items"]:
                    reply = reply_item["snippet"]
                    
                    # Extract date and time separately from publishedAt for replies
                    reply_published_at = reply["publishedAt"]
                    reply_published_date, reply_published_time = reply_published_at.split('T')
                    
                    comments.append([
                        reply["authorDisplayName"],
                        reply_published_date,  # Separate column for date
                        reply_published_time,  # Separate column for time
                        reply["likeCount"],
                        reply["textOriginal"],
                        top_level_comment["videoId"],
#                         item["snippet"]["isPublic"]  
                        # Assuming replies have the same 'public' status as the top-level comment
                    ])

        # Check if there are more pages of comments
        request = youtube.commentThreads().list_next(request, response)

    # Create DataFrame
    dfx = pd.DataFrame(comments, 
                    columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id'])
    return dfx

# %%
df = get_comments(mir_chara_vids[1])
df.head(3)
# Out:
#             author published_date published_time  like_count  \
# 0  @stillediting93     2024-05-17      09:26:13Z           0
# 1          @R5hiva     2024-05-16      09:50:47Z           0
# 2          @R5hiva     2024-05-16      09:50:16Z           0
#
#                                                 text     video_id
# 0                                     Too many ads 😢  w6a9wvFugT4
# 1                    নকুরবাবু ও এল ডো রাডো কবে আসবে?  w6a9wvFugT4
# 2  ভুষুন্ডির মাঠে আর ছুটি কাটালো অনুপম কবে আসবে??...  w6a9wvFugT4

# %%
print(df.shape)
# df = df.sort_values(by='like_count', ascending=False)
df.head(5)
# Out:
# (61650, 6)
#                       author published_date published_time  like_count  \
# 0           @user-qb7mu2li4e     2024-04-28      08:28:11Z           0
# 1        @SownakBhattacharya     2024-03-31      21:16:34Z           0
# 2             @kartikroy9906     2024-03-29      10:02:26Z           4
# 3       @Shikkhito-Chhotolok     2024-03-29      10:45:28Z           1
# 4  @abhijnanroychowdhury5846     2024-03-01      23:38:27Z           3
#
#                                                 text     video_id
# 0                               আমরা আছি আমরা থাকবো😊  aitb---aDYM
# 1                                                  .  aitb---aDYM
# 2                    Boru angla boi ta kar kar priyo  aitb---aDYM
# 3                                               Amar  aitb---aDYM
# 4  Amar priya lekhaker Khub priya ekta galpo ja s...  aitb---aDYM

# %%
df = df.drop_duplicates().reset_index(drop=True)
df.shape
# Out:
# (307, 7)

# %% [markdown]
# **Its Working**

# %%
print(f'{len(mirer_thek_vids)} {len(mir_soho_vids)} {len(mir_chara_vids)}')
# Out:
# 70 180 246

# %% [markdown]
# ## Mir er Thek

# %%
def create_comdf(vid_list): 
    # main df
    columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id']
    main_df = pd.DataFrame(columns=columns)
#     print(main_df)

    total_iterations = len(vid_list)

    for index, vid in tqdm(enumerate(list(vid_list)), total=total_iterations):
        if vid == 'oMFX3tano6A':
            continue
        else:
            temp_df = get_comments(vid=vid)
            temp_df = temp_df.drop_duplicates().reset_index(drop=True)
            main_df = pd.concat([main_df, temp_df], ignore_index=True)
    return main_df

# %%
main_df0 = create_comdf(mirer_thek_vids[:40])
print(f'Length of DataFrame is {main_df0.shape}')
main_df0.head(5)
# Out:
#   0%|          | 0/40 [00:04<?, ?it/s]
#
# KeyboardInterrupt

# %%
main_df0['video_id'].nunique()

# %%
main_df = create_comdf(mirer_thek_vids[40:])
print(f'Length of DataFrame is {main_df.shape}')
main_df.head(5)

# %%
print(main_df['video_id'].nunique())

main = pd.concat([main_df0, main_df], ignore_index=True)
print(main['video_id'].nunique())
print(main.shape)
main.head()

# %%
main['published_time'] = main['published_time'].str[:-1]
main['published_date'] = pd.to_datetime(main['published_date'])


main.to_csv('mirer_thek_comment.csv', index=False)

df = pd.read_csv('/kaggle/working/mirer_thek_comment.csv')
print(df.shape)
df.head(4)

# %%
df.video_id.nunique()

# %%
li = [1,2,3,4,5,6]
li[:3]

# %% [markdown]
# ## Mir Soho Comments

# %%
import os

def delete_file(file_path):
    """
    Deletes the specified file if it exists.

    Parameters:
    file_path (str): The path to the file to be deleted.
    """
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"File '{file_path}' has been deleted.")
    else:
        print(f"File '{file_path}' not found.")

# %%
print(mir_soho_vids[137])
print(len(mir_soho_vids))
print(len(mir_soho_vids[:30]))
print(len(mir_soho_vids[30:60]))
print(len(mir_soho_vids[80:120]))
print(len(mir_soho_vids[120:160]))
# Out:
# oMFX3tano6A
# 180
# 30
# 30
# 40
# 40

# %%
main_df0 = create_comdf(mir_soho_vids[:30])
print(f'Length of DataFrame is {main_df0.shape}')
main_df0.head(5)
# Out:
# 100%|██████████| 30/30 [15:31<00:00, 31.06s/it]
# Length of DataFrame is (83641, 7)
#                     author published_date published_time like_count  \
# 0  @Storysuspensecomedy123     2023-01-25      15:41:04Z          1
# 1           @kumkumdas9131     2023-01-25      15:31:14Z          0
# 2        @golamrabbani8765     2023-01-25      15:28:34Z          0
# 3       @dipayangoswmi2016     2023-01-25      15:28:33Z          0
# 4         @homayunalam2589     2023-01-25      15:24:09Z          0
#
#                                                 text     video_id public
# 0  Mirda তুমি আমাকে তৈরি করে নাও। আমার জীবন ও ভবি...  EcIDh5OEOyo   True
# 1        তারানাথ তান্ত্রিকের অপেক্ষায় থাকলাম মীর দা  EcIDh5OEOyo   True
# 2      আপনার কন্ঠে শার্লক হোমস আবারও শুনতে চাই❤️❤️❤️  EcIDh5OEOyo   True
# 3  Ah! Atlast you have come. Great to hear your m...  EcIDh5OEOyo   True
# 4         নতুন জার্নি শুরু করলাম। এর যেনো শেষ না হয়।  EcIDh5OEOyo   True

# %%
main_df0.isna().sum()
# Out:
# author            0
# published_date    0
# published_time    0
# like_count        0
# text              0
# video_id          0
# public            0
# dtype: int64

# %%
file_path = '/kaggle/working/mir_soho_u30.csv'
delete_file(file_path)
# Out:
# File '/kaggle/working/mir_soho_u30.csv' has been deleted.

# %%
main_df0.drop(['public'], axis=1, inplace=True)
# Save the DataFrame to a Parquet file
main_df0.to_parquet('/kaggle/working/mir_soho_u30.parquet', index=False)

# Reload the DataFrame from the Parquet file
df = pd.read_parquet('/kaggle/working/mir_soho_u30.parquet')

# Verify the shape and data types of the reloaded DataFrame
print(df.shape)
print(df.dtypes)
df.head(4)
# Out:
# (83641, 6)
# author            object
# published_date    object
# published_time    object
# like_count         int64
# text              object
# video_id          object
# dtype: object
#                     author published_date published_time  like_count  \
# 0  @Storysuspensecomedy123     2023-01-25      15:41:04Z           1
# 1           @kumkumdas9131     2023-01-25      15:31:14Z           0
# 2        @golamrabbani8765     2023-01-25      15:28:34Z           0
# 3       @dipayangoswmi2016     2023-01-25      15:28:33Z           0
#
#                                                 text     video_id
# 0  Mirda তুমি আমাকে তৈরি করে নাও। আমার জীবন ও ভবি...  EcIDh5OEOyo
# 1        তারানাথ তান্ত্রিকের অপেক্ষায় থাকলাম মীর দা  EcIDh5OEOyo
# 2      আপনার কন্ঠে শার্লক হোমস আবারও শুনতে চাই❤️❤️❤️  EcIDh5OEOyo
# 3  Ah! Atlast you have come. Great to hear your m...  EcIDh5OEOyo

# %% [markdown]
# ### 30-->60

# %%
main_df1 = create_comdf(mir_soho_vids[30:60])
print(f'Length of DataFrame is {main_df1.shape}')
print(main_df1.video_id.nunique())
main_df1.head(5)
# Out:
# 100%|██████████| 30/30 [12:03<00:00, 24.12s/it]
# Length of DataFrame is (117710, 6)
# 30
#                            author published_date published_time like_count  \
# 0            @souhardyamandal1360     2024-05-15      09:16:48Z          0
# 1  @shibendumahapatraofficial8680     2024-05-14      20:44:28Z          0
# 2             @debasishsarkar5534     2024-05-14      16:11:25Z          0
# 3         @theentertainboypro7884     2024-05-14      11:17:54Z          0
# 4                        @ab2001k     2024-05-13      14:41:33Z          0
#
#                                                 text     video_id
# 0  আজ ০৯/১০/২০২২ সাল । একটি কমেন্ট রেখে গেলাম শেষ...  -2y3Gp8X-Us
# 1                               Ses ta vison koster😞  -2y3Gp8X-Us
# 2                                        অমর জীবন !❤  -2y3Gp8X-Us
# 3                                       Asadharan ❤❤  -2y3Gp8X-Us
# 4                                 আসামের "বরাক" নদী?  -2y3Gp8X-Us

# %%
main_df1.to_parquet('/kaggle/working/mir_soho_u60.parquet', index=False)

# Reload the DataFrame from the Parquet file
df = pd.read_parquet('/kaggle/working/mir_soho_u60.parquet')

# Verify the shape and data types of the reloaded DataFrame
print(df.shape)
print(df.dtypes)
df.head(4)
# Out:
# (117710, 6)
# author            object
# published_date    object
# published_time    object
# like_count         int64
# text              object
# video_id          object
# dtype: object
#                            author published_date published_time  like_count  \
# 0            @souhardyamandal1360     2024-05-15      09:16:48Z           0
# 1  @shibendumahapatraofficial8680     2024-05-14      20:44:28Z           0
# 2             @debasishsarkar5534     2024-05-14      16:11:25Z           0
# 3         @theentertainboypro7884     2024-05-14      11:17:54Z           0
#
#                                                 text     video_id
# 0  আজ ০৯/১০/২০২২ সাল । একটি কমেন্ট রেখে গেলাম শেষ...  -2y3Gp8X-Us
# 1                               Ses ta vison koster😞  -2y3Gp8X-Us
# 2                                        অমর জীবন !❤  -2y3Gp8X-Us
# 3                                       Asadharan ❤❤  -2y3Gp8X-Us

# %% [markdown]
# ### 60--->90

# %%
main_df2 = create_comdf(mir_soho_vids[60:90])
print(f'Length of DataFrame is {main_df2.shape}')
print(main_df2.video_id.nunique())
main_df2.head(5)
# Out:
# 100%|██████████| 30/30 [06:52<00:00, 13.73s/it]
# Length of DataFrame is (66050, 6)
# 30
#                       author published_date published_time like_count  \
# 0                @sdatta9451     2024-05-16      05:21:00Z          0
# 1         @madhumitapaul7424     2024-05-10      11:16:26Z          0
# 2  @shirshanathmukherjee2926     2024-05-10      10:26:27Z          0
# 3      @soumyadipguharoy8354     2024-05-07      08:19:31Z          0
# 4              @Ritam_Zecus_     2024-05-04      04:28:21Z          0
#
#                                                 text     video_id
# 0  Sb e thik chilo. Last insta t selok comment kr...  LxfGhYKmEkg
# 1                                         V.V.V.NICE  LxfGhYKmEkg
# 2  Shimultala giye ei golpo ta chalate hoto 🧐kich...  LxfGhYKmEkg
# 3                                            Seraaa🔥  LxfGhYKmEkg
# 4                                     Kub valo goppo  LxfGhYKmEkg

# %%
main_df2.to_parquet('/kaggle/working/mir_soho_u90.parquet', index=False)

# Reload the DataFrame from the Parquet file
df = pd.read_parquet('/kaggle/working/mir_soho_u90.parquet')

# Verify the shape and data types of the reloaded DataFrame
print(df.shape)
print(df.dtypes)
df.head(4)
# Out:
# (66050, 6)
# author            object
# published_date    object
# published_time    object
# like_count         int64
# text              object
# video_id          object
# dtype: object
#                       author published_date published_time  like_count  \
# 0                @sdatta9451     2024-05-16      05:21:00Z           0
# 1         @madhumitapaul7424     2024-05-10      11:16:26Z           0
# 2  @shirshanathmukherjee2926     2024-05-10      10:26:27Z           0
# 3      @soumyadipguharoy8354     2024-05-07      08:19:31Z           0
#
#                                                 text     video_id
# 0  Sb e thik chilo. Last insta t selok comment kr...  LxfGhYKmEkg
# 1                                         V.V.V.NICE  LxfGhYKmEkg
# 2  Shimultala giye ei golpo ta chalate hoto 🧐kich...  LxfGhYKmEkg
# 3                                            Seraaa🔥  LxfGhYKmEkg

# %%
main_df3 = create_comdf(mir_soho_vids[90:120])
print(f'Length of DataFrame is {main_df3.shape}')
print(main_df3.video_id.nunique())
main_df3.head(5)
# Out:
# 100%|██████████| 30/30 [06:43<00:00, 13.47s/it]
# Length of DataFrame is (75752, 6)
# 30
#                  author published_date published_time like_count  \
# 0  @AbdullahZaman-ru5rd     2024-05-16      00:00:33Z          0
# 1       @Papai.ghosh.47     2024-05-13      18:02:54Z          0
# 2    @Arifulislam-ni5fi     2024-04-28      19:20:01Z          0
# 3   @arabindasikdar2433     2024-04-23      07:35:22Z          0
# 4  @naturegardening4729     2024-04-16      14:44:31Z          0
#
#                                                 text     video_id
# 0                                               ❤❤❤❤  C3YpWl4vLoo
# 1  তারানাথের গল্প সবগুলোই ভালো \nএই গল্প টিও খুব ...  C3YpWl4vLoo
# 2        ঢাকা, বাংলাদেশ থেকে একজন নিয়মিত শ্রোতা 🇧🇩❤️  C3YpWl4vLoo
# 3                                               Good  C3YpWl4vLoo
# 4  🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰🥰...  C3YpWl4vLoo

# %%
main_df3.to_parquet('/kaggle/working/mir_soho_u120.parquet', index=False)

# Reload the DataFrame from the Parquet file
df = pd.read_parquet('/kaggle/working/mir_soho_u120.parquet')

# Verify the shape and data types of the reloaded DataFrame
print(df.shape)
print(df.dtypes)
df.head(4)
# Out:
# (75752, 6)
# author            object
# published_date    object
# published_time    object
# like_count         int64
# text              object
# video_id          object
# dtype: object
#                  author published_date published_time  like_count  \
# 0  @AbdullahZaman-ru5rd     2024-05-16      00:00:33Z           0
# 1       @Papai.ghosh.47     2024-05-13      18:02:54Z           0
# 2    @Arifulislam-ni5fi     2024-04-28      19:20:01Z           0
# 3   @arabindasikdar2433     2024-04-23      07:35:22Z           0
#
#                                                 text     video_id
# 0                                               ❤❤❤❤  C3YpWl4vLoo
# 1  তারানাথের গল্প সবগুলোই ভালো \nএই গল্প টিও খুব ...  C3YpWl4vLoo
# 2        ঢাকা, বাংলাদেশ থেকে একজন নিয়মিত শ্রোতা 🇧🇩❤️  C3YpWl4vLoo
# 3                                               Good  C3YpWl4vLoo

# %%
main_df4 = create_comdf(mir_soho_vids[120:150])
print(f'Length of DataFrame is {main_df4.shape}')
print(main_df4.video_id.nunique())
main_df4.head(5)
# Out:
# 100%|██████████| 30/30 [04:24<00:00,  8.80s/it]
# Length of DataFrame is (61650, 6)
# 29
#                       author published_date published_time like_count  \
# 0           @user-qb7mu2li4e     2024-04-28      08:28:11Z          0
# 1        @SownakBhattacharya     2024-03-31      21:16:34Z          0
# 2             @kartikroy9906     2024-03-29      10:02:26Z          4
# 3       @Shikkhito-Chhotolok     2024-03-29      10:45:28Z          1
# 4  @abhijnanroychowdhury5846     2024-03-01      23:38:27Z          3
#
#                                                 text     video_id
# 0                               আমরা আছি আমরা থাকবো😊  aitb---aDYM
# 1                                                  .  aitb---aDYM
# 2                    Boru angla boi ta kar kar priyo  aitb---aDYM
# 3                                               Amar  aitb---aDYM
# 4  Amar priya lekhaker Khub priya ekta galpo ja s...  aitb---aDYM

# %%
main_df4.to_parquet('/kaggle/working/mir_soho_u150.parquet', index=False)

# Reload the DataFrame from the Parquet file
df = pd.read_parquet('/kaggle/working/mir_soho_u150.parquet')

# Verify the shape and data types of the reloaded DataFrame
print(df.shape)
print(df.dtypes)
df.head(4)
# Out:
# (61650, 6)
# author            object
# published_date    object
# published_time    object
# like_count         int64
# text              object
# video_id          object
# dtype: object
#                  author published_date published_time  like_count  \
# 0      @user-qb7mu2li4e     2024-04-28      08:28:11Z           0
# 1   @SownakBhattacharya     2024-03-31      21:16:34Z           0
# 2        @kartikroy9906     2024-03-29      10:02:26Z           4
# 3  @Shikkhito-Chhotolok     2024-03-29      10:45:28Z           1
#
#                               text     video_id
# 0             আমরা আছি আমরা থাকবো😊  aitb---aDYM
# 1                                .  aitb---aDYM
# 2  Boru angla boi ta kar kar priyo  aitb---aDYM
# 3                             Amar  aitb---aDYM

# %% [markdown]
# ### 150 --> 180

# %%
main_df5 = create_comdf(mir_soho_vids[150:])
print(f'Length of DataFrame is {main_df5.shape}')
print(main_df5.video_id.nunique())
main_df5.head(5)
# Out:
# 100%|██████████| 30/30 [03:32<00:00,  7.07s/it]
# Length of DataFrame is (40595, 6)
# 30
#                     author published_date published_time like_count  \
# 0       @rimachowdhury4671     2024-05-12      23:34:51Z          0
# 1             @khokon42011     2024-05-07      10:32:23Z          0
# 2  @monikabhattacharya5280     2024-05-05      06:20:20Z          0
# 3   @nayanaachatterjee2006     2024-04-26      05:25:16Z          1
# 4        @mousumimanna7397     2024-04-24      10:51:22Z          0
#
#                                                 text     video_id
# 0  Blanche monnier er golpo r sathe 90 prcnt mele...  Ix9y3MFnm20
# 1  Sayak Aman er golpo sob udvot faltu \nEkdom va...  Ix9y3MFnm20
# 2   This is actually a true story of blanche Monnier  Ix9y3MFnm20
# 3  Koto bar je ei golpo ta sunechi taar thik nei ...  Ix9y3MFnm20
# 4                       😊😊😊😊❤❤❤❤😂😂😂😂🎉🎉🎉🎉😢😢😢😢😮😮😮😮😅😅😅😅  Ix9y3MFnm20

# %%
main_df5.to_parquet('/kaggle/working/mir_soho_u180.parquet', index=False)

# Reload the DataFrame from the Parquet file
df = pd.read_parquet('/kaggle/working/mir_soho_u180.parquet')

# Verify the shape and data types of the reloaded DataFrame
print(df.shape)
print(df.dtypes)
df.head(4)
# Out:
# (40595, 6)
# author            object
# published_date    object
# published_time    object
# like_count         int64
# text              object
# video_id          object
# dtype: object
#                     author published_date published_time  like_count  \
# 0       @rimachowdhury4671     2024-05-12      23:34:51Z           0
# 1             @khokon42011     2024-05-07      10:32:23Z           0
# 2  @monikabhattacharya5280     2024-05-05      06:20:20Z           0
# 3   @nayanaachatterjee2006     2024-04-26      05:25:16Z           1
#
#                                                 text     video_id
# 0  Blanche monnier er golpo r sathe 90 prcnt mele...  Ix9y3MFnm20
# 1  Sayak Aman er golpo sob udvot faltu \nEkdom va...  Ix9y3MFnm20
# 2   This is actually a true story of blanche Monnier  Ix9y3MFnm20
# 3  Koto bar je ei golpo ta sunechi taar thik nei ...  Ix9y3MFnm20

# %%
df1 = pd.read_parquet('/kaggle/working/mir_soho_u30.parquet')
df2 = pd.read_parquet('/kaggle/working/mir_soho_u60.parquet')
df3 = pd.read_parquet('/kaggle/working/mir_soho_u90.parquet')
df4 = pd.read_parquet('/kaggle/working/mir_soho_u120.parquet')
df5 = pd.read_parquet('/kaggle/working/mir_soho_u150.parquet')
df6 = pd.read_parquet('/kaggle/working/mir_soho_u180.parquet')

mirsoho = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)
print(f'Length of DataFrame is {mirsoho.shape}')
# Out:
# Length of DataFrame is (445398, 6)

# %%
mirsoho.isna().sum()
# Out:
# author            0
# published_date    0
# published_time    0
# like_count        0
# text              0
# video_id          0
# dtype: int64

# %%
mirsoho = mirsoho.drop_duplicates().reset_index(drop=True)

print(mirsoho['video_id'].nunique())
print(mirsoho.shape)
mirsoho.head()
# Out:
# 180
# (445398, 6)
#                     author published_date published_time  like_count  \
# 0  @Storysuspensecomedy123     2023-01-25      15:41:04Z           1
# 1           @kumkumdas9131     2023-01-25      15:31:14Z           0
# 2        @golamrabbani8765     2023-01-25      15:28:34Z           0
# 3       @dipayangoswmi2016     2023-01-25      15:28:33Z           0
# 4         @homayunalam2589     2023-01-25      15:24:09Z           0
#
#                                                 text     video_id
# 0  Mirda তুমি আমাকে তৈরি করে নাও। আমার জীবন ও ভবি...  EcIDh5OEOyo
# 1        তারানাথ তান্ত্রিকের অপেক্ষায় থাকলাম মীর দা  EcIDh5OEOyo
# 2      আপনার কন্ঠে শার্লক হোমস আবারও শুনতে চাই❤️❤️❤️  EcIDh5OEOyo
# 3  Ah! Atlast you have come. Great to hear your m...  EcIDh5OEOyo
# 4         নতুন জার্নি শুরু করলাম। এর যেনো শেষ না হয়।  EcIDh5OEOyo

# %%
# !mkdir /kaggle/working/final_data

# %%
mirsoho.to_parquet('/kaggle/working/final_data/mir_soho_comment.parquet', index=False)

# %%
df = pd.read_parquet('/kaggle/working/final_data/mir_soho_comment.parquet')
df
# Out:
#                          author published_date published_time  like_count  \
# 0       @Storysuspensecomedy123     2023-01-25      15:41:04Z           1
# 1                @kumkumdas9131     2023-01-25      15:31:14Z           0
# 2             @golamrabbani8765     2023-01-25      15:28:34Z           0
# 3            @dipayangoswmi2016     2023-01-25      15:28:33Z           0
# 4              @homayunalam2589     2023-01-25      15:24:09Z           0
# ...                         ...            ...            ...         ...
# 445393             @blazoknight     2019-01-03      13:16:32Z          12
# 445394  @shafinyeazsiddique7920     2019-01-03      13:16:28Z           0
# 445395          @sksabirali5345     2019-01-03      13:16:26Z           2
# 445396        @premankitaroy650     2019-01-03      13:16:26Z           2
# 445397        @reeyambiswas5181     2019-01-03      17:50:18Z           0
#
#                                                      text     video_id
# 0       Mirda তুমি আমাকে তৈরি করে নাও। আমার জীবন ও ভবি...  EcIDh5OEOyo
# 1             তারানাথ তান্ত্রিকের অপেক্ষায় থাকলাম মীর দা  EcIDh5OEOyo
# 2           আপনার কন্ঠে শার্লক হোমস আবারও শুনতে চাই❤️❤️❤️  EcIDh5OEOyo
# 3       Ah! Atlast you have come. Great to hear your m...  EcIDh5OEOyo
# 4              নতুন জার্নি শুরু করলাম। এর যেনো শেষ না হয়।  EcIDh5OEOyo
# ...                                                   ...          ...
# 445393  Big fan you guys are doing a great job...keep ...  VfsywJMaJak
# 445394                                               Good  VfsywJMaJak
# 445395                                                1st  VfsywJMaJak
# 445396                                      1st comment 😊  VfsywJMaJak
# 445397                   Come on to my Facebook messenger  VfsywJMaJak
#
# [445398 rows x 6 columns]

# %% [markdown]
# ## Mir Chara Commenta

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df1 = pd.DataFrame(columns=columns)
print(main_df1)

total_iterations = len(mir_chara_vids[:71])

for index, vid in tqdm(enumerate(list(mir_chara_vids[:71])), total=total_iterations):
    temp_df = get_comments(vid=vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df1 = pd.concat([main_df1, temp_df], ignore_index=True)

# %%
print(f'Length of DataFrame is {main_df1.shape}')
main_df1.head(5)

# %%
main_df1['video_id'].nunique()

# %%
main_df1.to_csv('mir_chara_comment_p1.csv', index=False)

df = pd.read_csv('/kaggle/working/mir_chara_comment_p1.csv')
df.head(4)

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df2 = pd.DataFrame(columns=columns)
print(main_df2)

total_iterations = len(mir_chara_vids[71:])

for index, vid in tqdm(enumerate(list(mir_chara_vids[71:])), total=total_iterations):
    temp_df = get_comments(vid=vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df2 = pd.concat([main_df2, temp_df], ignore_index=True)

# %%
print(f'Length of DataFrame is {main_df2.shape}')
print(main_df2['video_id'].nunique())


main_df2.to_csv('mir_chara_comment_p2.csv', index=False)

df = pd.read_csv('/kaggle/working/mir_chara_comment_p2.csv')
df.head(4)

# %% [markdown]
# ### part3

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df3 = pd.DataFrame(columns=columns)
print(main_df3)

total_iterations = len(mir_chara_vids[121:])

for index, vid in tqdm(enumerate(list(mir_chara_vids[122:])), total=total_iterations):
#     print(index)
    temp_df = get_comments(vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df3 = pd.concat([main_df3, temp_df], ignore_index=True)

# %%
temp_df = get_comments(mir_chara_vids[121])
temp_df = temp_df.drop_duplicates().reset_index(drop=True)
main_df3 = pd.concat([main_df3, temp_df], ignore_index=True)

# %%
print(f'Length of DataFrame is {main_df3.shape}')
print(main_df3['video_id'].nunique())


main_df3.to_csv('mir_chara_comment_p3.csv', index=False)

df = pd.read_csv('/kaggle/working/mir_chara_comment_p3.csv')
df.head(4)

# %%
len(mir_soho_vids)

# %% [markdown]
# ## Part 1

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df = pd.DataFrame(columns=columns)
print(main_df)

total_iterations = len(mir_soho_vids[:50])

for index, vid in tqdm(enumerate(list(mir_soho_vids[:50])), total=total_iterations):
    temp_df = get_comments(vid=vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df = pd.concat([main_df, temp_df], ignore_index=True)

# %%
print(f'Length of DataFrame is {main_df.shape}')
print(main_df['video_id'].nunique())


main_df.to_csv('mir_soho_comment_p1.csv', index=False)

df = pd.read_csv('/kaggle/working/mir_soho_comment_p1.csv')
df.head(4)

# %% [markdown]
# ## Part 2

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df = pd.DataFrame(columns=columns)
print(main_df)

total_iterations = len(mir_soho_vids[50:100])

for index, vid in tqdm(enumerate(list(mir_soho_vids[50:100])), total=total_iterations):
    temp_df = get_comments(vid=vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df = pd.concat([main_df, temp_df], ignore_index=True)

# %%
print(f'Length of DataFrame is {main_df.shape}')
print(main_df['video_id'].nunique())


temp_df.to_csv('mir_soho_comment_p2.csv', index=False)

df = pd.read_csv('/kaggle/working/mir_soho_comment_p2.csv')
df.head(4)

# %%
temp_df = df.drop_duplicates().reset_index(drop=True)
print(f'Length of DataFrame is {temp_df.shape}')

# %% [markdown]
# ## Part 3

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df = pd.DataFrame(columns=columns)

total_iterations = len(mir_soho_vids[100:150])

for index, vid in tqdm(enumerate(list(mir_soho_vids[100:150])), total=total_iterations):
    temp_df = get_comments(vid=vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df = pd.concat([main_df, temp_df], ignore_index=True)

print(f'Length of DataFrame is {main_df.shape}')
print(main_df['video_id'].nunique())

# %%
# temp_df = main_df.drop_duplicates().reset_index(drop=True)
# print(f'Length of DataFrame is {temp_df.shape}')

# temp_df.to_csv('mir_soho_comment_p3.csv', index=False)

df = pd.read_csv('/kaggle/working/mir_soho_comment_p3.csv')
df.head(4)
df.shape

# %% [markdown]
# ## Part 4

# %%
# main df
columns=['author', 'published_date', 'published_time', 'like_count', 'text', 'video_id', 'public']
main_df = pd.DataFrame(columns=columns)

total_iterations = len(mir_soho_vids[150:200])

for index, vid in tqdm(enumerate(list(mir_soho_vids[150:200])), total=total_iterations):
    temp_df = get_comments(vid=vid)
    temp_df = temp_df.drop_duplicates().reset_index(drop=True)
    main_df = pd.concat([main_df, temp_df], ignore_index=True)

print(f'Length of DataFrame is {main_df.shape}')
print(main_df['video_id'].nunique())

# %% [markdown]
# ## EDA

# %%
data = pd.read_csv('/kaggle/input/media-study/mirer_thek_data.csv')

print(data.shape)
data.head(4)

# %%
data = pd.read_csv('/kaggle/input/media-study/mir_soho_data.csv')

print(data.shape)
data.head(4)

# %%
data = pd.read_csv('/kaggle/input/media-study/mir_chara_data.csv')

print(data.shape)
data.head(4)

# %%
data = pd.read_csv('/kaggle/input/media-study/mirer_thek_comment.csv')

print(data.shape)
data.head(2)
